# %% [markdown]
# # HexagDLy CNN example
#
# This notebook presents a small CNN example to illustrate the application of HexagDLy in a CNN for classification.

# %%
import pytorch_hexagdly as hexagdly
from hexagdly_tools import plot_hextensor
from example_utils import toy_data, toy_dataset, model

import torch
import torch.nn.functional as F
import torch.nn as nn

import importlib
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/tanguy/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# First, the hexagonal image data is created via the provided `toy_dataset` class. In this example, hexagonally sampled images with different shapes at different positions are generated. The training and validation sets contains 128 and 64 images of each shape respectively.
# The possible shapes to choose from are:
#
# **['small_hexagon', 'medium_hexagon', 'snowflake_1', 'snowflake_2', 'snowflake_3', 'snowflake_4', 'double_hex']**

# %%
shape_list = ['snowflake_2', 'snowflake_3', 'snowflake_4', 'double_hex']
val_data = toy_dataset(shape_list, 32)
val_data.create()
val_dataloader = val_data.to_dataloader()
train_data = toy_dataset(shape_list, 128)
train_data.create()
train_dataloader = train_data.to_dataloader()

# %% [markdown]
# The lines below show a few example images from the validation set:

# %%
# %matplotlib inline
val_tensor = val_data.to_torch_tensor()
plot_hextensor(val_tensor, image_range=(0,16), channel_range=(0,None), figname='val_examples')

# %% [markdown]
# Next, a small CNN network is created that uses the convolution and pooling operations provided by HexagDLy. The API is the same as in PyTorch.

# %%
class fc(nn.Module):
    def __init__(self, in_features, out_features):
        super(fc, self).__init__()
        self.ops = nn.Sequential(nn.Linear(in_features, out_features),
                                 nn.ReLU())
    def forward(self, input):
        return self.ops(input)


class hex_model(nn.Module):
    def __init__(self, nout, plot=False):
        super(hex_model, self).__init__()
        self.name = 'hex_model'
        self.plot=plot
        self.hexconv_1 = hexagdly.Conv2d(in_channels = 1, out_channels = 4, \
                                         kernel_size = 2, stride = 1, bias=True,
                                         share_neighbors='ring'
                                         )
        self.hexpool = hexagdly.MaxPool2d(kernel_size = 2, stride = 2)
        self.hexconv_2 = hexagdly.Conv2d(4, 8, kernel_size=1, stride=1, bias=True,
                                         share_neighbors='ring'
                                         )

        self.fc = nn.Sequential(fc(512, 128),
                                nn.Dropout(0.5),
                                fc(128, 64),
                                nn.Linear(64, nout))

    def forward(self, x, ni=0):
        x = self.hexconv_1(x)
        
        # Option to plot first conv layer output
        if self.plot:
            plot_hextensor(x, image_range=(ni,ni+1), channel_range=(0,None), figname='after_first_hexconv')
            
        x = F.relu(x)
        x = self.hexpool(x)
        x = self.hexconv_2(x)
        
        # Option to plot second conv layer output
        if self.plot:
            plot_hextensor(x, image_range=(ni,ni+1), channel_range=(0,None), figname='after_second_hexconv')
            
        x = F.relu(x)
        x = x.view(-1, 512)
        x = self.fc(x)
        return x

# %% [markdown]
#  The training and validation data are loaded into the model and the CNN is trained for a few epochs:

# %%
try:
    from torchinfo import summary
except ImportError:
    import subprocess, sys
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'torchinfo', '-q'])
    from torchinfo import summary
net = hex_model(len(shape_list))
summary(net, input_size=(1, 1, 16, 16))
# Out:
# /home/tanguy/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:187: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12020). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# hex_model                                [1, 4]                    --
# ├─Conv2d: 1-1                            [1, 4, 16, 16]            44
# ├─MaxPool2d: 1-2                         [1, 4, 8, 8]              --
# ├─Conv2d: 1-3                            [1, 8, 8, 8]              136
# ├─Sequential: 1-4                        [1, 4]                    --
# │    └─fc: 2-1                           [1, 128]                  --
# │    │    └─Sequential: 3-1              [1, 128]                  65,664
# │    └─Dropout: 2-2                      [1, 128]                  --
# │    └─fc: 2-3                           [1, 64]                   --
# │    │    └─Sequential: 3-2              [1, 64]                   8,256
# │    └─Linear: 2-4                       [1, 4]                    260
# ==========================================================================================
# Total params: 74,360
# Trainable params: 74,360
# Non-trainable params: 0
# Total mult-adds (M): 0.08
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.30
# Estimated Total Size (MB): 0.31
# ==========================================================================================

# %%
epochs = 10
cnn_model = model(train_dataloader, val_dataloader, net, epochs=epochs)
cnn_model.train()
cnn_model.save_current()
# Out:
# Epoch 1
# epoch: 1 (0.250) training -    16 batches -> mean loss: 1.391, lr: 0.005, mean acc.: 26.56 %
# epoch: 1 (0.500) training -    32 batches -> mean loss: 1.434, lr: 0.005, mean acc.: 21.88 %
# epoch: 1 (0.750) training -    48 batches -> mean loss: 1.413, lr: 0.005, mean acc.: 24.22 %
# epoch: 1 (1.000) training -    64 batches -> mean loss: 1.359, lr: 0.005, mean acc.: 30.47 %
# epoch: 1 (0.250) train_lc -    16 batches -> mean loss: 1.370, lr: 0.005, mean acc.: 31.25 %
# epoch: 1 (0.500) train_lc -    32 batches -> mean loss: 1.377, lr: 0.005, mean acc.: 30.47 %
# epoch: 1 (0.750) train_lc -    48 batches -> mean loss: 1.351, lr: 0.005, mean acc.: 35.94 %
# epoch: 1 (1.000) train_lc -    64 batches -> mean loss: 1.350, lr: 0.005, mean acc.: 32.03 %
# epoch: 1 (1.000) val_lc -    16 batches -> mean loss: 1.397, lr: 0.005, mean acc.: 30.47 %
# Epoch 2
# epoch: 2 (1.250) training -    16 batches -> mean loss: 1.377, lr: 0.005, mean acc.: 31.25 %
# epoch: 2 (1.500) training -    32 batches -> mean loss: 1.371, lr: 0.005, mean acc.: 32.03 %
# epoch: 2 (1.750) training -    48 batches -> mean loss: 1.358, lr: 0.005, mean acc.: 30.47 %
# epoch: 2 (2.000) training -    64 batches -> mean loss: 1.375, lr: 0.005, mean acc.: 31.25 %
# epoch: 2 (1.250) train_lc -    16 batches -> mean loss: 1.314, lr: 0.005, mean acc.: 44.53 %
# epoch: 2 (1.500) train_lc -    32 batches -> mean loss: 1.338, lr: 0.005, mean acc.: 38.28 %
# epoch: 2 (1.750) train_lc -    48 batches -> mean loss: 1.366, lr: 0.005, mean acc.: 32.81 %
# epoch: 2 (2.000) train_lc -    64 batches -> mean loss: 1.365, lr: 0.005, mean acc.: 34.38 %
# epoch: 2 (2.000) val_lc -    16 batches -> mean loss: 1.390, lr: 0.005, mean acc.: 30.47 %
# Epoch 3
# epoch: 3 (2.250) training -    16 batches -> mean loss: 1.352, lr: 0.005, mean acc.: 35.16 %
# epoch: 3 (2.500) training -    32 batches -> mean loss: 1.396, lr: 0.005, mean acc.: 25.00 %
# epoch: 3 (2.750) training -    48 batches -> mean loss: 1.396, lr: 0.005, mean acc.: 20.31 %
# epoch: 3 (3.000) training -    64 batches -> mean loss: 1.359, lr: 0.005, mean acc.: 31.25 %
# epoch: 3 (2.250) train_lc -    16 batches -> mean loss: 1.299, lr: 0.005, mean acc.: 41.41 %
# epoch: 3 (2.500) train_lc -    32 batches -> mean loss: 1.333, lr: 0.005, mean acc.: 36.72 %
# epoch: 3 (2.750) train_lc -    48 batches -> mean loss: 1.333, lr: 0.005, mean acc.: 28.12 %
# epoch: 3 (3.000) train_lc -    64 batches -> mean loss: 1.356, lr: 0.005, mean acc.: 28.91 %
# epoch: 3 (3.000) val_lc -    16 batches -> mean loss: 1.370, lr: 0.005, mean acc.: 27.34 %
# Epoch 4
# epoch: 4 (3.250) training -    16 batches -> mean loss: 1.353, lr: 0.005, mean acc.: 29.69 %
# epoch: 4 (3.500) training -    32 batches -> mean loss: 1.361, lr: 0.005, mean acc.: 28.12 %
# epoch: 4 (3.750) training -    48 batches -> mean loss: 1.332, lr: 0.005, mean acc.: 39.84 %
# epoch: 4 (4.000) training -    64 batches -> mean loss: 1.321, lr: 0.005, mean acc.: 35.94 %
# epoch: 4 (3.250) train_lc -    16 batches -> mean loss: 1.296, lr: 0.005, mean acc.: 34.38 %
# epoch: 4 (3.500) train_lc -    32 batches -> mean loss: 1.283, lr: 0.005, mean acc.: 41.41 %
# epoch: 4 (3.750) train_lc -    48 batches -> mean loss: 1.267, lr: 0.005, mean acc.: 42.97 %
# epoch: 4 (4.000) train_lc -    64 batches -> mean loss: 1.327, lr: 0.005, mean acc.: 33.59 %
# epoch: 4 (4.000) val_lc -    16 batches -> mean loss: 1.336, lr: 0.005, mean acc.: 30.47 %
# Epoch 5
# epoch: 5 (4.250) training -    16 batches -> mean loss: 1.310, lr: 0.005, mean acc.: 35.16 %
# epoch: 5 (4.500) training -    32 batches -> mean loss: 1.327, lr: 0.005, mean acc.: 40.62 %
# epoch: 5 (4.750) training -    48 batches -> mean loss: 1.224, lr: 0.005, mean acc.: 44.53 %
# epoch: 5 (5.000) training -    64 batches -> mean loss: 1.227, lr: 0.005, mean acc.: 43.75 %
# epoch: 5 (4.250) train_lc -    16 batches -> mean loss: 1.161, lr: 0.005, mean acc.: 52.34 %
# epoch: 5 (4.500) train_lc -    32 batches -> mean loss: 1.169, lr: 0.005, mean acc.: 53.91 %
# epoch: 5 (4.750) train_lc -    48 batches -> mean loss: 1.142, lr: 0.005, mean acc.: 53.91 %
# epoch: 5 (5.000) train_lc -    64 batches -> mean loss: 1.173, lr: 0.005, mean acc.: 54.69 %
# epoch: 5 (5.000) val_lc -    16 batches -> mean loss: 1.196, lr: 0.005, mean acc.: 49.22 %
# Epoch 6
# epoch: 6 (5.250) training -    16 batches -> mean loss: 1.214, lr: 0.005, mean acc.: 43.75 %
# epoch: 6 (5.500) training -    32 batches -> mean loss: 1.136, lr: 0.005, mean acc.: 44.53 %
# epoch: 6 (5.750) training -    48 batches -> mean loss: 0.995, lr: 0.005, mean acc.: 57.81 %
# epoch: 6 (6.000) training -    64 batches -> mean loss: 1.043, lr: 0.005, mean acc.: 49.22 %
# epoch: 6 (5.250) train_lc -    16 batches -> mean loss: 0.951, lr: 0.005, mean acc.: 58.59 %
# epoch: 6 (5.500) train_lc -    32 batches -> mean loss: 0.920, lr: 0.005, mean acc.: 52.34 %
# epoch: 6 (5.750) train_lc -    48 batches -> mean loss: 1.093, lr: 0.005, mean acc.: 45.31 %
# epoch: 6 (6.000) train_lc -    64 batches -> mean loss: 0.986, lr: 0.005, mean acc.: 50.78 %
# epoch: 6 (6.000) val_lc -    16 batches -> mean loss: 1.027, lr: 0.005, mean acc.: 45.31 %
# Epoch 7
# epoch: 7 (6.250) training -    16 batches -> mean loss: 0.964, lr: 0.005, mean acc.: 57.03 %
# epoch: 7 (6.500) training -    32 batches -> mean loss: 0.908, lr: 0.005, mean acc.: 57.03 %
# epoch: 7 (6.750) training -    48 batches -> mean loss: 0.917, lr: 0.005, mean acc.: 66.41 %
# epoch: 7 (7.000) training -    64 batches -> mean loss: 0.914, lr: 0.005, mean acc.: 46.88 %
# epoch: 7 (6.250) train_lc -    16 batches -> mean loss: 0.794, lr: 0.005, mean acc.: 60.94 %
# epoch: 7 (6.500) train_lc -    32 batches -> mean loss: 0.828, lr: 0.005, mean acc.: 61.72 %
# epoch: 7 (6.750) train_lc -    48 batches -> mean loss: 0.753, lr: 0.005, mean acc.: 66.41 %
# epoch: 7 (7.000) train_lc -    64 batches -> mean loss: 0.829, lr: 0.005, mean acc.: 61.72 %
# epoch: 7 (7.000) val_lc -    16 batches -> mean loss: 0.819, lr: 0.005, mean acc.: 61.72 %
# Epoch 8
# epoch: 8 (7.250) training -    16 batches -> mean loss: 0.886, lr: 0.005, mean acc.: 61.72 %
# epoch: 8 (7.500) training -    32 batches -> mean loss: 0.813, lr: 0.005, mean acc.: 65.62 %
# epoch: 8 (7.750) training -    48 batches -> mean loss: 0.833, lr: 0.005, mean acc.: 59.38 %
# epoch: 8 (8.000) training -    64 batches -> mean loss: 0.828, lr: 0.005, mean acc.: 55.47 %
# epoch: 8 (7.250) train_lc -    16 batches -> mean loss: 0.922, lr: 0.005, mean acc.: 42.97 %
# epoch: 8 (7.500) train_lc -    32 batches -> mean loss: 0.931, lr: 0.005, mean acc.: 43.75 %
# epoch: 8 (7.750) train_lc -    48 batches -> mean loss: 0.916, lr: 0.005, mean acc.: 42.97 %
# epoch: 8 (8.000) train_lc -    64 batches -> mean loss: 0.912, lr: 0.005, mean acc.: 41.41 %
# epoch: 8 (8.000) val_lc -    16 batches -> mean loss: 1.007, lr: 0.005, mean acc.: 36.72 %
# Epoch 9
# epoch: 9 (8.250) training -    16 batches -> mean loss: 0.912, lr: 0.005, mean acc.: 52.34 %
# epoch: 9 (8.500) training -    32 batches -> mean loss: 0.873, lr: 0.005, mean acc.: 56.25 %
# epoch: 9 (8.750) training -    48 batches -> mean loss: 0.754, lr: 0.005, mean acc.: 64.84 %
# epoch: 9 (9.000) training -    64 batches -> mean loss: 0.724, lr: 0.005, mean acc.: 70.31 %
# epoch: 9 (8.250) train_lc -    16 batches -> mean loss: 0.665, lr: 0.005, mean acc.: 76.56 %
# epoch: 9 (8.500) train_lc -    32 batches -> mean loss: 0.652, lr: 0.005, mean acc.: 78.12 %
# epoch: 9 (8.750) train_lc -    48 batches -> mean loss: 0.642, lr: 0.005, mean acc.: 82.03 %
# epoch: 9 (9.000) train_lc -    64 batches -> mean loss: 0.665, lr: 0.005, mean acc.: 78.91 %
# epoch: 9 (9.000) val_lc -    16 batches -> mean loss: 0.682, lr: 0.005, mean acc.: 72.66 %
# Epoch 10
# epoch: 10 (9.250) training -    16 batches -> mean loss: 0.703, lr: 0.005, mean acc.: 66.41 %
# epoch: 10 (9.500) training -    32 batches -> mean loss: 0.547, lr: 0.005, mean acc.: 81.25 %
# epoch: 10 (9.750) training -    48 batches -> mean loss: 0.720, lr: 0.005, mean acc.: 68.75 %
# epoch: 10 (10.000) training -    64 batches -> mean loss: 0.685, lr: 0.005, mean acc.: 67.97 %
# epoch: 10 (9.250) train_lc -    16 batches -> mean loss: 0.604, lr: 0.005, mean acc.: 76.56 %
# epoch: 10 (9.500) train_lc -    32 batches -> mean loss: 0.725, lr: 0.005, mean acc.: 68.75 %
# epoch: 10 (9.750) train_lc -    48 batches -> mean loss: 0.725, lr: 0.005, mean acc.: 60.16 %
# epoch: 10 (10.000) train_lc -    64 batches -> mean loss: 0.682, lr: 0.005, mean acc.: 68.75 %
# epoch: 10 (10.000) val_lc -    16 batches -> mean loss: 0.718, lr: 0.005, mean acc.: 64.84 %

# %% [markdown]
# Looking at the learning curves, one can see that the model does learn to distinguish the different shapes. The accuracy of course depends on the number of training events, the number of epochs the model is trained and on the combination of shapes in the training data.

# %%
cnn_model.plot_lc()

# %%
# Visualise the learned hex kernels after training.

import torch, numpy as np, matplotlib.pyplot as plt
from matplotlib.patches import RegularPolygon
from matplotlib.collections import PatchCollection
from pytorch_hexagdly import _tap_offset

HEX_RADIUS = 0.54

def hex_xy(gr, gc):
    return gc * np.sqrt(3) / 2, -(gr + np.mod(gc, 2) * 0.5)

def build_kernel_positions(n):
    """Map each sub-kernel cell (i,r,c) to its hex display position.
    _tap_offset returns (output - input), so input position = center - tap_offset.
    """
    c = n
    pos = {}
    for i in range(n + 1):
        rows = 2 * n + 1 - i
        cols = 1 if i == 0 else 2
        for r in range(rows):
            for col in range(cols):
                dr, dc = _tap_offset(n, i, r, col)
                pos[(i, r, col)] = hex_xy(c - dr, c - dc)
    return pos

def plot_hex_kernels(conv_layer, layer_name):
    net.eval()
    conv_layer._materialize_shared_kernels()
    n = conv_layer.hexbase_size
    out_ch = conv_layer.out_channels
    in_ch = conv_layer.in_channels
    pos = build_kernel_positions(n)

    n_filters = out_ch * in_ch
    ncols = min(8, n_filters)
    nrows = int(np.ceil(n_filters / ncols))
    fig, axes = plt.subplots(nrows, ncols,
                             figsize=(ncols * (n + 2), nrows * (n + 2.5)))
    axes = np.array(axes).flatten()

    all_xy = list(pos.values())
    pad = HEX_RADIUS + 0.1
    xlim = (min(x for x, y in all_xy) - pad, max(x for x, y in all_xy) + pad)
    ylim = (min(y for x, y in all_xy) - pad, max(y for x, y in all_xy) + pad)

    for idx in range(n_filters):
        oc = idx // in_ch
        ic = idx % in_ch
        ax = axes[idx]

        vals, hexagons, xy_list = [], [], []
        for i in range(n + 1):
            rows = 2 * n + 1 - i
            cols = 1 if i == 0 else 2
            ki = getattr(conv_layer, f'kernel{i}')[oc, ic].detach().cpu().numpy()
            for r in range(rows):
                for c in range(cols):
                    hx, hy = pos[(i, r, c)]
                    v = float(ki[r, c])
                    hexagons.append(RegularPolygon((hx, hy), 6,
                                                   radius=HEX_RADIUS,
                                                   orientation=np.pi / 6))
                    vals.append(v)
                    xy_list.append((hx, hy))

        vmax = max(abs(v) for v in vals) or 1.0
        pc = PatchCollection(hexagons, cmap='RdBu_r', alpha=0.9,
                             edgecolors='k', linewidth=0.8)
        pc.set_array(np.array(vals))
        pc.set_clim(-vmax, vmax)
        ax.add_collection(pc)

        fontsize = max(5, 8 - n)
        for (hx, hy), v in zip(xy_list, vals):
            ax.text(hx, hy, f'{v:.2f}', ha='center', va='center',
                    fontsize=fontsize, fontweight='bold')

        ax.set_xlim(*xlim)
        ax.set_ylim(*ylim)
        ax.set_aspect('equal')
        ax.set_axis_off()
        ax.set_title(f'out={oc} in={ic}', fontsize=7)

    for idx in range(n_filters, len(axes)):
        axes[idx].set_visible(False)

    fig.suptitle(f'{layer_name}  (kernel_size={n})', fontsize=11)
    plt.tight_layout()
    plt.show()

plot_hex_kernels(net.hexconv_1, 'hexconv_1')
plot_hex_kernels(net.hexconv_2, 'hexconv_2')

# %% [markdown]
# To probe the model in detail, a test image is created in which a hexagonal shape is located at a given position. By changing the `px` and `py` values (corresponding to the column and row of the center of the shape) the shape can be moved to an arbitrary position.

# %%
test_shape = 'snowflake_3'
image = toy_data(test_shape, 16, 16, 1, 1, px=10, py=10)
testimage = image.to_torch_tensor()
plot_hextensor(testimage, figname='test_shape')

# %% [markdown]
# In the next step, the trained model parameters are loaded into the model with the plot parameter set to `True` to visualize the featuremaps:

# %%
net_plot = hex_model(len(shape_list), plot=True)
net_plot.load_state_dict(torch.load('./hex_model_'+str(epochs)+'.ptmodel', weights_only=True))
plot_out = net_plot(testimage)
net_out = net(testimage)

# %% [markdown]
# To get the probability of the test_shape to belong to a certain class, the CNN output has to be fed into a softmax function:

# %%
probs = F.softmax(net_out, dim=-1)
sp, si = torch.sort(probs,-1)
for n,(p, i) in enumerate(zip(sp.data.numpy()[0][::-1], si.data.numpy()[0][::-1])):
    if n==0 and shape_list[i]==test_shape:
        print('CNN is CORRECT!')
    elif n==0 and shape_list[i]!=test_shape:
        print('CNN is wrong...')
    print('\t',n+1,' with',np.round(100*p,3), '% ',shape_list[i])
# Out:
# CNN is wrong...
# 	 1  with 53.144 %  double_hex
# 	 2  with 46.708 %  snowflake_3
# 	 3  with 0.148 %  snowflake_4
# 	 4  with 0.0 %  snowflake_2
